# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
shp2 = "TPBoundary_new-2021/TPBoundary_new(2021).shp"
sf_SETP = gpd.read_file(shp2)
sf_SETP.plot(edgecolor='black')
# Out:
# <Axes: >

# %%
sf_SETP.within(85,32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sf_SETP.within(85,32)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopandas\base.py:1896, in GeoPandasBase.within(self, other, align)
#    1784 def within(self, other, align=True):
#    1785     """Returns a ``Series`` of ``dtype('bool')`` with value ``True`` for
#    1786     each aligned geometry that is within `other`.
#    1787
#    (...)
#    1894     GeoSeries.contains
#    1895     """
# -> 1896     return _binary_op("within", self, other, align)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopandas\base.py:59, in _binary_op(op, this, other, align, *args, **kwargs)
#      56 def _binary_op(op, this, other, align, *args, **kwargs):
#      57     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
# ...

# %%
sf_SETP.head(2)
# Out:
#    OBJECTID    Shape_Leng  Shape_Le_1  Shape_Area  \
# 0         1  1.009397e+07  103.706434  299.850832
#
#                                             geometry
# 0  POLYGON ((71.85561 39.44270, 71.87762 39.44663...

# %%
boundary.xy[1]
# Out:
# array('d', [39.44270423800003, 39.44663493300004, 39.441593527000066, 39.43910727900004, 39.44063561100006, 39.441430214000036, 39.44449750700005, 39.44679829000006, 39.44606611300003, 39.45093711000004, 39.45429030500003, 39.45880820200006, 39.462731087000066, 39.468174401000056, 39.46942816600006, 39.46681655400005, 39.455355732000044, 39.44382312500005, 39.429852260000075, 39.42457534000005, 39.438884218000055, 39.442948458000046, 39.44768640400008, 39.45289673000008, 39.458897001000025, 39.45848288500008, 39.46184208400007, 39.45583128100003, 39.452451523000036, 39.45516769500006, 39.46020330300007, 39.462746286000026, 39.46738159500006, 39.47228952200004, 39.48486740000004, 39.48764098200007, 39.490385641000046, 39.49480491600008, 39.499302569000065, 39.50426214000004, 39.50949166800007, 39.51348640500004, 39.51705384200005, 39.52157758800007, 39.52287761600007, 39.52210328500007, 39.521378036000044, 39.516519078000044, 39.51532078900004, 39.51227917600005, 39.511029343000075, 3
# ...

# %%
for boundary in sf_SETP.boundary:
    print(boundary.xy)
# Out:
# (array('d', [71.85560895500004, 71.87762173100003, 71.90404888300003, 71.93193691500005, 71.95161450900008, 71.97612988900005, 71.99641994100006, 72.01759271900005, 72.03777965800003, 72.06279692100003, 72.08348488100006, 72.10178562600004, 72.12009605800006, 72.13585690700006, 72.15165676500004, 72.17141003600005, 72.19465332200008, 72.20874811100003, 72.22801504500006, 72.25438571800004, 72.28057042800003, 72.30822690500008, 72.32811128200007, 72.34926693000006, 72.36345428400006, 72.38664475200005, 72.40679483900004, 72.42591820800004, 72.45381929700005, 72.47323388100006, 72.49010979900004, 72.51373323000007, 72.54318049500006, 72.57812057200005, 72.61702703600008, 72.63873156200003, 72.65202625000006, 72.66852948800005, 72.68731063400008, 72.71381216300006, 72.73160537100006, 72.76118602600008, 72.78418819700005, 72.80933075200005, 72.82847057300006, 72.83427607000004, 72.83971174700008, 72.85688391100007, 72.86111726900003, 72.87186004900008, 72.87869324100006, 72.8846341410000
# ...

# %%
dir(sf_SETP)
# Out:
# ['OBJECTID',
#  'Shape_Area',
#  'Shape_Le_1',
#  'Shape_Leng',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...
